# %%
# %load_ext sql

# %%
import configparser
import psycopg2
import boto3

# %%
# CONFIG
config = configparser.ConfigParser()
config.read('dwh.cfg')
LOG_DATA=config.get('S3','lOG_DATA')
SONG_DATA=config.get('S3','SONG_DATA')
LOG_JSONPATH=config.get('S3','LOG_JSONPATH')
REGION=config.get('S3','REGION')
ARN=config.get('IAM_ROLE','ARN')

KEY = config.get('AWS','KEY')
SECRET = config.get('AWS','SECRET')
DB_NAME=config.get('CLUSTER','DB_NAME')
DB_USER=config.get('CLUSTER','DB_USER')
DB_PASSWORD=config.get('CLUSTER','DB_PASSWORD')
DB_PORT=config.get('CLUSTER','DB_PORT')
DB_ENDPOINT=config.get('CLUSTER','HOST')

# %%
s3 = boto3.resource('s3',
                    region_name="us-west-2",
                    aws_access_key_id=KEY,
                    aws_secret_access_key=SECRET)

# %%
sampleDbBucket =  s3.Bucket("udacity-dend")
for obj in sampleDbBucket.objects.filter(Prefix="log_data"):
    print(obj)
# for obj in sampleDbBucket.objects.all():
#     print(obj)
# Out:
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-01-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-02-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-03-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-04-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-05-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-06-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-07-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-08-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-09-events.json')
# ...

# %%
conn_string="postgresql://{}:{}@{}:{}/{}".format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT,DB_NAME)
print(conn_string)
# %sql $conn_string
# Out:
# postgresql://awsuser:AWS3udacity@redshift-cluster-1.c0r0jwmx88s6.us-west-2.redshift.amazonaws.com:5439/dev

# %%
# %%sql
# drop table stations;
# drop table trips

# %%
# %%sql
# select count(*) from stations;

# %%
# %%sql
# select count(*) from trips;

# %%
# %%sql
# drop view stl_load_errors;

# %%
# %%sql
# select * from stl_load_errors;

# %%
# %%sql
# select count(*) from staging_events;
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.c0r0jwmx88s6.us-west-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(8056,)]

# %%
# %%sql
# select * from staging_events limit 10;
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.c0r0jwmx88s6.us-west-2.redshift.amazonaws.com:5439/dev
# 10 rows affected.
# [(None, 'Logged In', 'Walter', 'M', 0, 'Frye', None, 'free', 'San Francisco-Oakland-Hayward, CA', 'GET', 'Home', Decimal('1540919166796'), 38, None, 200, 1541105830796, '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', 39),
#  (None, 'Logged In', 'Kaylee', 'F', 0, 'Summers', None, 'free', 'Phoenix-Mesa-Scottsdale, AZ', 'GET', 'Home', Decimal('1540344794796'), 139, None, 200, 1541106106796, '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"', 8),
# ...

# %%
# %%sql
# select count(*) from staging_songs;
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.c0r0jwmx88s6.us-west-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(29792,)]

# %%
# %%sql
# --select COLUMN_NAME,DATA_TYPE,CHARACTER_MAXIMUM_LENGTH from information_schema.columns where TABLE_NAME='staging_events';
# select COLUMN_NAME,DATA_TYPE,CHARACTER_MAXIMUM_LENGTH from information_schema.columns where TABLE_NAME='songplays'
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.c0r0jwmx88s6.us-west-2.redshift.amazonaws.com:5439/dev
# 9 rows affected.
# [('sessionid', 'integer', None),
#  ('userid', 'integer', None),
#  ('user_agent', 'character varying', 256),
#  ('location', 'character varying', 256),
#  ('artistid', 'character varying', 256),
#  ('songid', 'character varying', 256),
#  ('level', 'character varying', 256),
#  ('playid', 'character varying', 32),
#  ('start_time', 'timestamp without time zone', None)]

# %%
# %%sql
# SELECT TIMESTAMP 'epoch' + ts/1000 * interval '1 second' AS start_time, *
#             FROM staging_events
#             WHERE page='NextSong'
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.c0r0jwmx88s6.us-west-2.redshift.amazonaws.com:5439/dev
# 11 rows affected.
# [(datetime.datetime(2018, 11, 1, 21, 1, 46), "Des'ree", 'Logged In', 'Kaylee', 'F', 1, 'Summers', Decimal('246'), 'free', 'Phoenix-Mesa-Scottsdale, AZ', 'PUT', 'NextSong', Decimal('1540344794796'), 139, 'You Gotta Be', 200, 1541106106796, '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"', 8),
#  (datetime.datetime(2018, 11, 1, 21, 5, 52), 'Mr Oizo', 'Logged In', 'Kaylee', 'F', 3, 'Summers', Decimal('144'), 'free', 'Phoenix-Mesa-Scottsdale, AZ', 'PUT', 'NextSong', Decimal('1540344794796'), 139, 'Flat 55', 200, 1541106352796, '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"', 8),
# ...

# %%
# %%sql
# SELECT distinct artist_id, artist_name, artist_location, artist_latitude, artist_longitude
#         FROM staging_songs
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.c0r0jwmx88s6.us-west-2.redshift.amazonaws.com:5439/dev
# 24 rows affected.
# [('AR73AIO1187B9AD57B', 'Western Addiction', 'San Francisco, CA', Decimal('37'), Decimal('-122')),
#  ('AR9Q9YC1187FB5609B', 'Quest_ Pup_ Kevo', 'New Jersey', None, None),
#  ('ARC1IHZ1187FB4E920', 'Jamie Cullum', '', None, None),
#  ('AR1C2IX1187B99BF74', 'Broken Spindles', '', None, None),
#  ('ARGE7G11187FB37E05', 'Cyndi Lauper', 'Brooklyn, NY', None, None),
#  ('ARSZ7L31187FB4E610', 'Devotchka', 'Denver, CO', Decimal('39'), Decimal('-104')),
#  ('ARBZIN01187FB362CC', 'Paris Hilton', '27', Decimal('1'), Decimal('103')),
#  ('ARZKCQM1257509D107', 'Dataphiles', '', None, None),
#  ('ARTC1LV1187B9A4858', 'The Bonzo Dog Band', "Goldsmith's College, Lewisham, Lo", Decimal('51'), Decimal('0')),
#  ('ARKYKXP11F50C47A6A', 'The Supersuckers', '', None, None),
#  ('ARA23XO1187B9AF18F', 'The Smithereens', 'Carteret, New Jersey', Decimal('40'), Decimal('-74')),
# ...

# %%
# %%sql
# INSERT INTO artists (artist_id, artist_name, artist_location, artist_latitude, artist_longitude)
#         SELECT distinct artist_id, artist_name, artist_location, artist_latitude, artist_longitude
#         FROM staging_songs
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.c0r0jwmx88s6.us-west-2.redshift.amazonaws.com:5439/dev
# (psycopg2.errors.UndefinedColumn) column "artist_latitude" of relation "artists" does not exist
#
# [SQL: INSERT INTO artists (artist_id, artist_name, artist_location, artist_latitude, artist_longitude)
#         SELECT distinct artist_id, artist_name, artist_location, artist_latitude, artist_longitude
#         FROM staging_songs]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
# %%sql
# SELECT COUNT(*) FROM users WHERE userid is null
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.c0r0jwmx88s6.us-west-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(0,)]

# %%
# %%sql
# SELECT distinct artist_id, artist_name, artist_location, artist_latitude, artist_longitude
#         FROM staging_songs
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.c0r0jwmx88s6.us-west-2.redshift.amazonaws.com:5439/dev
# 24 rows affected.
# [('AR73AIO1187B9AD57B', 'Western Addiction', 'San Francisco, CA', Decimal('37'), Decimal('-122')),
#  ('AR9Q9YC1187FB5609B', 'Quest_ Pup_ Kevo', 'New Jersey', None, None),
#  ('ARC1IHZ1187FB4E920', 'Jamie Cullum', '', None, None),
#  ('AR1C2IX1187B99BF74', 'Broken Spindles', '', None, None),
#  ('ARGE7G11187FB37E05', 'Cyndi Lauper', 'Brooklyn, NY', None, None),
#  ('ARSZ7L31187FB4E610', 'Devotchka', 'Denver, CO', Decimal('39'), Decimal('-104')),
#  ('ARBZIN01187FB362CC', 'Paris Hilton', '27', Decimal('1'), Decimal('103')),
#  ('ARZKCQM1257509D107', 'Dataphiles', '', None, None),
#  ('ARTC1LV1187B9A4858', 'The Bonzo Dog Band', "Goldsmith's College, Lewisham, Lo", Decimal('51'), Decimal('0')),
#  ('ARKYKXP11F50C47A6A', 'The Supersuckers', '', None, None),
#  ('ARA23XO1187B9AF18F', 'The Smithereens', 'Carteret, New Jersey', Decimal('40'), Decimal('-74')),
# ...

# %%
# %%time
staging_events_copy = ("""copy staging_events
                          from {}
                          credentials 'aws_iam_role={}'
                          json as {}
                          region {}  timeformat as 'epochmillisecs';
                       """).format(LOG_DATA, ARN, LOG_JSONPATH, REGION)
# %sql $staging_events_copy
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.c0r0jwmx88s6.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# Wall time: 3.5 s
# []

# %%
# %%time
# %%sql
COPY staging_events
        FROM 's3://udacity-dend/log_data/2018/11/2018-11-01-events.json'
        ACCESS_KEY_ID 'AKIARVAAQ7CSOXGLFICN'
        SECRET_ACCESS_KEY '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'
        json  's3://udacity-dend/log_json_path.json'
        
        region 'us-west-2'

# %%
# %%time
staging_songs_copy = ("""copy staging_songs
                          from 's3://udacity-dend/song_data/A/A/A/'
                          credentials 'aws_iam_role={}'
                          json as 'auto'
                          region {} ;
                       """).format(ARN, REGION)

# %sql $staging_songs_copy

# %%
# %%time
# %%sql
COPY airport
        FROM 's3://udacity-dend/song_data/A/A/A/'
        ACCESS_KEY_ID 'AKIARVAAQ7CSOXGLFICN'
        SECRET_ACCESS_KEY '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'
        json as 'auto'
        region 'us-west-2'

# %%
# %%sql
# SELECT timestamp without time zone 'epoch' + ts/1000 * interval '1 second' as time_key,
#                            timestamp without time zone 'epoch' + ts/1000 * interval '1 second' as start_time,
#                            EXTRACT(hour from start_time) AS hour,
#                            EXTRACT(day from start_time) AS day,
#                            EXTRACT(week from start_time) AS week,
#                            EXTRACT(month from start_time) AS month,
#                            EXTRACT(year from start_time) AS year,
#                            EXTRACT(weekday from start_time) AS weekday
#                     FROM staging_events where page='NextSong' limit 10;

# %%
# %%sql
# INSERT INTO time (time_key, start_time, hour, day, week, month, year, weekday)
#                     SELECT timestamp without time zone 'epoch' + ts/1000 * interval '1 second' as time_key,
#                            timestamp without time zone 'epoch' + ts/1000 * interval '1 second' as start_time,
#                            EXTRACT(hour from start_time) AS hour,
#                            EXTRACT(day from start_time) AS day,
#                            EXTRACT(week from start_time) AS week,
#                            EXTRACT(month from start_time) AS month,
#                            EXTRACT(year from start_time) AS year,
#                            EXTRACT(weekday from start_time) AS weekday
#                     FROM staging_events where page='NextSong'

# %%
# %sql select count(*) from time;
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.c0r0jwmx88s6.us-west-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(0,)]

# %%
# %%sql
# select * from songplays order by playid;
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.c0r0jwmx88s6.us-west-2.redshift.amazonaws.com:5439/dev
# 640 rows affected.
# [('006feb7440dc10b9220bda22263a46e6', datetime.datetime(2018, 11, 26, 8, 30, 57), 44, 'paid', 'SORAHAG12AB0182BD0', 'AR8UZXF1187B9AB868', 781, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  ('006feb7440dc10b9220bda22263a46e6', datetime.datetime(2018, 11, 26, 8, 30, 57), 44, 'paid', 'SORAHAG12AB0182BD0', 'AR8UZXF1187B9AB868', 781, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  ('00e577f3b8b36dc80fc16b387bfb5ec4', datetime.datetime(2018, 11, 3, 17, 59, 1), 15, 'paid', 'SOHTKMO12AB01843B0', 'AR5EYTL1187B98EDA0', 199, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
# ...

# %%
# %%sql
# select * from songplays  order by songplay_key;
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.c0r0jwmx88s6.us-west-2.redshift.amazonaws.com:5439/dev
# (psycopg2.errors.UndefinedColumn) column "songplay_key" does not exist in songplays
#
# [SQL: select * from songplays  order by songplay_key;]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
# %%sql
# SELECT
#                 md5(events.sessionid || events.start_time) songplay_id,
#                 events.start_time,
#                 events.userid,
#                 events.level,
#                 songs.song_id,
#                 songs.artist_id,
#                 events.sessionid,
#                 events.location,
#                 events.useragent
#                 FROM (SELECT TIMESTAMP 'epoch' + ts/1000 * interval '1 second' AS start_time, *
#             FROM staging_events
#             WHERE page='NextSong') events
#             JOIN staging_songs songs
#             ON events.song = songs.title
#                 AND events.artist = songs.artist_name
#                 AND events.length = songs.duration
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.c0r0jwmx88s6.us-west-2.redshift.amazonaws.com:5439/dev
# 0 rows affected.
# []
